# %%
import pandas as pandas
df = pandas.read_csv("IMDB_FR.tsv.gz", sep="\t", compression="gzip")
df
# Out:
# C:\Users\pujad\AppData\Local\Temp\ipykernel_22732\136472582.py:2: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv("IMDB_FR.tsv.gz", sep="\t", compression="gzip")
#             tconst  ordering                                    title region  \
# 0        tt0000591         2                        L'enfant prodigue     FR
# 1        tt0000591         2                        L'enfant prodigue     FR
# 2        tt0000886         2                                   Hamlet     FR
# 3        tt0001101         4            La Clémence d'Abraham Lincoln     FR
# 4        tt0001101         4            La Clémence d'Abraham Lincoln     FR
# ...            ...       ...                                      ...    ...
# 624041  tt30007864         6  The American Society of Magical Negroes     FR
# 624042  tt30007864         6  The American Society of Magical Negroes     FR
# ...
